# %% [markdown]
# # Dynamic Web Applications Project effort
# An analysis of students' self-reported effort to complete projects required for the class.

# %%
# %matplotlib inline
import numpy as np
from scipy import stats
from scipy.stats import norm
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('white')
sns.set_context('talk')

# %%
# Reconstructed survey results from http://dwa15.com/Projects.../P2

project2_hours = [20, 12, 9,    5,  5,  16, 10, 18, 10,  12,
                  6,   6, 5,    3,  6,  12, 10,  8, 5.5, 14,
                  6,   4, 3.5,  6,  6, 4.5,  8, 11,  6,   5,
                  8,  10, 8,   16, 10,   8, 12, 18, 3.5,  5,
                  24, 16, 11,  10,  6,  10,  5, 12,  5, 6.5,
                  15, 16]

# %%
plt.hist(project2_hours, bins=15)
plt.title("Self-reported effort on DWA15 Project 2 (SP-2016)")
plt.xlabel("Hours of effort")
plt.ylabel("Count")
plt.show();
